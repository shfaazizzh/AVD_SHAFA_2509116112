# %% [markdown]
# #**Global Healthy Diet Cost Analysis (2017–2024)**

# %% [markdown]
# #**Import Library**

# %%
import pandas as pd

# %% [markdown]
# #**Memuat Dataset**

# %%
import pandas as pd

file = "/content/price_of_healthy_diet_clean (1).csv"

df = pd.read_csv(file)

df
# Out:
#       country_code   country  region  year  cost_healthy_diet_ppp_usd  \
# 0                8   Albania  Africa  2017                       3.04
# 1                8   Albania  Africa  2018                       3.13
# 2                8   Albania  Africa  2019                       3.32
# 3                8   Albania  Africa  2020                       3.40
# 4                8   Albania  Africa  2021                       3.49
# ...            ...       ...     ...   ...                        ...
# 1374           894    Zambia  Europe  2021                       3.28
# 1375           894    Zambia  Europe  2022                       3.61
# 1376           894    Zambia  Europe  2023                       3.81
# 1377           894    Zambia  Europe  2024                       3.99
# 1378           716  Zimbabwe  Europe  2017                       3.54
#
#       annual_cost_healthy_diet_usd  cost_vegetables_ppp_usd  \
# 0                          1109.60                      NaN
# ...

# %%
df.head(2)
# Out:
#    country_code  country  region  year  cost_healthy_diet_ppp_usd  \
# 0             8  Albania  Africa  2017                       3.04
# 1             8  Albania  Africa  2018                       3.13
#
#    annual_cost_healthy_diet_usd  cost_vegetables_ppp_usd  cost_fruits_ppp_usd  \
# 0                       1109.60                      NaN                  NaN
# 1                       1142.45                      NaN                  NaN
#
#    total_food_components_cost cost_category     data_quality
# 0                         NaN     High Cost  Estimated value
# 1                         NaN     High Cost  Estimated value

# %%
df.tail()
# Out:
#       country_code   country  region  year  cost_healthy_diet_ppp_usd  \
# 1374           894    Zambia  Europe  2021                       3.28
# 1375           894    Zambia  Europe  2022                       3.61
# 1376           894    Zambia  Europe  2023                       3.81
# 1377           894    Zambia  Europe  2024                       3.99
# 1378           716  Zimbabwe  Europe  2017                       3.54
#
#       annual_cost_healthy_diet_usd  cost_vegetables_ppp_usd  \
# 1374                       1197.20                     0.31
# 1375                       1317.65                      NaN
# 1376                       1390.65                      NaN
# 1377                       1456.35                      NaN
# 1378                       1292.10                      NaN
#
#       cost_fruits_ppp_usd  total_food_components_cost cost_category  \
# 1374                 0.36                        0.67     High Cost
# ...

# %% [markdown]
# #**Business Understanding**

# %% [markdown]
# #**Business Objective**

# %% [markdown]
# Business objective dari dataset price_of_healthy_diet_clean.csv adalah untuk menganalisis dan membandingkan biaya diet sehat di berbagai negara guna mengetahui tingkat keterjangkauan makanan sehat berdasarkan kondisi ekonomi masing-masing negara. Analisis ini bertujuan mengidentifikasi negara dengan biaya diet tertinggi dan terendah, serta melihat hubungan antara biaya diet sehat dengan indikator ekonomi seperti GDP per kapita, sehingga dapat mendukung pengambilan keputusan dalam kebijakan ketahanan pangan, perencanaan anggaran, dan penelitian terkait aksesibilitas makanan sehat secara global.

# %% [markdown]
# #**Assess Situation**

# %% [markdown]
# menunjukkan bahwa terdapat perbedaan signifikan dalam biaya diet sehat antar negara yang dipengaruhi oleh kondisi ekonomi, tingkat pendapatan, dan daya beli masyarakat.

# %% [markdown]
# #**Analytic Goals Project Plan**

# %% [markdown]
# Dalam Dataset ini dilakukan:
#
#     -Analisis Deskriptif Biaya Diet Sehat
#     -Analisis Komparatif dan Pengelompokan Negara
#     -Analisis Hubungan dengan Faktor Ekonomi
